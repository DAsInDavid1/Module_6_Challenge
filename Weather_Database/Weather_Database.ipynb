# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 762

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]  
        # Append the city information into the city_data list
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                         "Current Description": city_description})
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | rikitea
# Processing Record 2 of Set 1 | bluff
# Processing Record 3 of Set 1 | castro
# Processing Record 4 of Set 1 | krumbach
# Processing Record 5 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 6 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 7 of Set 1 | victoria
# Processing Record 8 of Set 1 | olden
# Processing Record 9 of Set 1 | ushuaia
# Processing Record 10 of Set 1 | palabuhanratu
# City not found. Skipping...
# Processing Record 11 of Set 1 | kahului
# Processing Record 12 of Set 1 | hobart
# Processing Record 13 of Set 1 | port hawkesbury
# Processing Record 14 of Set 1 | khatanga
# Processing Record 15 of Set 1 | faanui
# Processing Record 16 of Set 1 | hilo
# Processing Record 17 of Set 1 | takoradi
# Processing Record 18 of Set 1 | port alfred
# Processing Record 19 of Set 1 | arraial do cabo
# Processing Record 20 of Set 1 | ilulissat
# Processing Record 21 of Set 1 | vardo
# Processing Record 22 of Set 1 | cansancao
# Processing Record 23 of Set 1 | tumannyy
# City not found. Skipping...
# Processing Record 24 of Set 1 | nikolskoye
# Processing Record 25 of Set 1 | punta arenas
# Processing Record 26 of Set 1 | scarborough
# Processing Record 27 of Set 1 | cockburn town
# Processing Record 28 of Set 1 | bintulu
# Processing Record 29 of Set 1 | evensk
# Processing Record 30 of Set 1 | saint-augustin
# Processing Record 31 of Set 1 | east london
# Processing Record 32 of Set 1 | tiksi
# Processing Record 33 of Set 1 | butaritari
# Processing Record 34 of Set 1 | pevek
# Processing Record 35 of Set 1 | kundiawa
# Processing Record 36 of Set 1 | albany
# Processing Record 37 of Set 1 | road town
# Processing Record 38 of Set 1 | cherskiy
# Processing Record 39 of Set 1 | marawi
# Processing Record 40 of Set 1 | phonhong
# Processing Record 41 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 42 of Set 1 | mount isa
# Processing Record 43 of Set 1 | yellowknife
# Processing Record 44 of Set 1 | pangody
# Processing Record 45 of Set 1 | alyangula
# Processing Record 46 of Set 1 | erenhot
# Processing Record 47 of Set 1 | portachuelo
# Processing Record 48 of Set 1 | mount gambier
# Processing Record 49 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 50 of Set 1 | kapaa
# Processing Record 1 of Set 2 | mar del plata
# Processing Record 2 of Set 2 | narok
# Processing Record 3 of Set 2 | woodward
# Processing Record 4 of Set 2 | ilanskiy
# Processing Record 5 of Set 2 | kenora
# Processing Record 6 of Set 2 | nantucket
# Processing Record 7 of Set 2 | kisangani
# Processing Record 8 of Set 2 | ribeira grande
# Processing Record 9 of Set 2 | crab hill
# City not found. Skipping...
# Processing Record 10 of Set 2 | gornopravdinsk
# Processing Record 11 of Set 2 | bambous virieux
# Processing Record 12 of Set 2 | te anau
# Processing Record 13 of Set 2 | barrow
# Processing Record 14 of Set 2 | lashio
# Processing Record 15 of Set 2 | blagoveshchensk
# Processing Record 16 of Set 2 | satinka
# Processing Record 17 of Set 2 | krivosheino
# Processing Record 18 of Set 2 | atuona
# Processing Record 19 of Set 2 | lata
# Processing Record 20 of Set 2 | bandarbeyla
# Processing Record 21 of Set 2 | bilibino
# Processing Record 22 of Set 2 | palmares
# Processing Record 23 of Set 2 | lincoln
# Processing Record 24 of Set 2 | metro
# Processing Record 25 of Set 2 | viransehir
# Processing Record 26 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 27 of Set 2 | busselton
# Processing Record 28 of Set 2 | port lincoln
# Processing Record 29 of Set 2 | souillac
# Processing Record 30 of Set 2 | luderitz
# Processing Record 31 of Set 2 | husavik
# Processing Record 32 of Set 2 | bethel
# Processing Record 33 of Set 2 | zabol
# Processing Record 34 of Set 2 | saint-philippe
# Processing Record 35 of Set 2 | sampit
# Processing Record 36 of Set 2 | san policarpo
# Processing Record 37 of Set 2 | bathsheba
# Processing Record 38 of Set 2 | cidreira
# Processing Record 39 of Set 2 | denpasar
# Processing Record 40 of Set 2 | hasaki
# Processing Record 41 of Set 2 | artsyz
# Processing Record 42 of Set 2 | kampene
# Processing Record 43 of Set 2 | ayan
# Processing Record 44 of Set 2 | mogadishu
# Processing Record 45 of Set 2 | vaini
# Processing Record 46 of Set 2 | los reyes
# Processing Record 47 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 48 of Set 2 | port hedland
# Processing Record 49 of Set 2 | carnarvon
# Processing Record 50 of Set 2 | new norfolk
# Processing Record 1 of Set 3 | hermanus
# Processing Record 2 of Set 3 | jurm
# Processing Record 3 of Set 3 | kieta
# Processing Record 4 of Set 3 | cape town
# Processing Record 5 of Set 3 | gatbo
# Processing Record 6 of Set 3 | avera
# Processing Record 7 of Set 3 | lagoa formosa
# Processing Record 8 of Set 3 | nanortalik
# Processing Record 9 of Set 3 | kavaratti
# Processing Record 10 of Set 3 | lavrentiya
# Processing Record 11 of Set 3 | tuktoyaktuk
# Processing Record 12 of Set 3 | bridlington
# Processing Record 13 of Set 3 | puerto ayora
# Processing Record 14 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 15 of Set 3 | clyde river
# Processing Record 16 of Set 3 | karaul
# City not found. Skipping...
# Processing Record 17 of Set 3 | longyearbyen
# Processing Record 18 of Set 3 | mataura
# Processing Record 19 of Set 3 | beyneu
# Processing Record 20 of Set 3 | jamestown
# Processing Record 21 of Set 3 | grindavik
# Processing Record 22 of Set 3 | dongsheng
# Processing Record 23 of Set 3 | ponta do sol
# Processing Record 24 of Set 3 | iqaluit
# Processing Record 25 of Set 3 | sungaipenuh
# Processing Record 26 of Set 3 | adrar
# Processing Record 27 of Set 3 | galiwinku
# City not found. Skipping...
# Processing Record 28 of Set 3 | banda aceh
# Processing Record 29 of Set 3 | vila franca do campo
# Processing Record 30 of Set 3 | pisco
# Processing Record 31 of Set 3 | kaitangata
# Processing Record 32 of Set 3 | nome
# Processing Record 33 of Set 3 | grand gaube
# Processing Record 34 of Set 3 | golyshmanovo
# Processing Record 35 of Set 3 | bengkulu
# Processing Record 36 of Set 3 | boone
# Processing Record 37 of Set 3 | port hardy
# Processing Record 38 of Set 3 | kodiak
# Processing Record 39 of Set 3 | mandurah
# Processing Record 40 of Set 3 | bredasdorp
# Processing Record 41 of Set 3 | usinsk
# Processing Record 42 of Set 3 | petropavlovsk-kamchatskiy
# Processing Record 43 of Set 3 | shirokiy
# Processing Record 44 of Set 3 | lagoa
# Processing Record 45 of Set 3 | port elizabeth
# Processing Record 46 of Set 3 | talnakh
# Processing Record 47 of Set 3 | zanjan
# Processing Record 48 of Set 3 | lompoc
# Processing Record 49 of Set 3 | tasiilaq
# Processing Record 50 of Set 3 | kruisfontein
# Processing Record 1 of Set 4 | broken hill
# Processing Record 2 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 3 of Set 4 | cap-aux-meules
# Processing Record 4 of Set 4 | maniitsoq
# Processing Record 5 of Set 4 | andenes
# Processing Record 6 of Set 4 | lakes entrance
# Processing Record 7 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 8 of Set 4 | manta
# Processing Record 9 of Set 4 | spoleto
# Processing Record 10 of Set 4 | okhotsk
# Processing Record 11 of Set 4 | batagay
# Processing Record 12 of Set 4 | tocopilla
# Processing Record 13 of Set 4 | georgetown
# Processing Record 14 of Set 4 | wanaka
# Processing Record 15 of Set 4 | ajdabiya
# Processing Record 16 of Set 4 | lufilufi
# Processing Record 17 of Set 4 | panorama
# Processing Record 18 of Set 4 | hithadhoo
# Processing Record 19 of Set 4 | fukuchiyama
# Processing Record 20 of Set 4 | esna
# Processing Record 21 of Set 4 | qaanaaq
# Processing Record 22 of Set 4 | namatanai
# Processing Record 23 of Set 4 | tuatapere
# Processing Record 24 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 25 of Set 4 | kalmunai
# Processing Record 26 of Set 4 | chuy
# Processing Record 27 of Set 4 | saldanha
# Processing Record 28 of Set 4 | karkaralinsk
# City not found. Skipping...
# Processing Record 29 of Set 4 | merauke
# Processing Record 30 of Set 4 | saint-pierre
# Processing Record 31 of Set 4 | mailsi
# Processing Record 32 of Set 4 | coahuayana
# Processing Record 33 of Set 4 | margate
# Processing Record 34 of Set 4 | thompson
# Processing Record 35 of Set 4 | beringovskiy
# Processing Record 36 of Set 4 | johnstown
# Processing Record 37 of Set 4 | mackay
# Processing Record 38 of Set 4 | glencoe
# Processing Record 39 of Set 4 | nishihara
# Processing Record 40 of Set 4 | nioki
# Processing Record 41 of Set 4 | sumbawa
# City not found. Skipping...
# Processing Record 42 of Set 4 | willmar
# Processing Record 43 of Set 4 | yulara
# Processing Record 44 of Set 4 | dikson
# Processing Record 45 of Set 4 | isangel
# Processing Record 46 of Set 4 | hervey bay
# Processing Record 47 of Set 4 | ferme-neuve
# Processing Record 48 of Set 4 | prosvet
# Processing Record 49 of Set 4 | hualmay
# Processing Record 50 of Set 4 | fortuna
# Processing Record 1 of Set 5 | phan rang
# City not found. Skipping...
# Processing Record 2 of Set 5 | tecoanapa
# Processing Record 3 of Set 5 | baykit
# Processing Record 4 of Set 5 | mikhaylovka
# Processing Record 5 of Set 5 | fairbanks
# Processing Record 6 of Set 5 | salon-de-provence
# Processing Record 7 of Set 5 | avarua
# Processing Record 8 of Set 5 | tabou
# Processing Record 9 of Set 5 | matadi
# Processing Record 10 of Set 5 | bayonne
# Processing Record 11 of Set 5 | baykalsk
# Processing Record 12 of Set 5 | torbay
# Processing Record 13 of Set 5 | jabiru
# City not found. Skipping...
# Processing Record 14 of Set 5 | tupiza
# Processing Record 15 of Set 5 | fare
# Processing Record 16 of Set 5 | tsihombe
# City not found. Skipping...
# Processing Record 17 of Set 5 | hauterive
# Processing Record 18 of Set 5 | katsuura
# Processing Record 19 of Set 5 | umm lajj
# Processing Record 20 of Set 5 | coolum beach
# Processing Record 21 of Set 5 | san patricio
# Processing Record 22 of Set 5 | chistogorskiy
# Processing Record 23 of Set 5 | padang
# Processing Record 24 of Set 5 | hirara
# Processing Record 25 of Set 5 | asfi
# Processing Record 26 of Set 5 | ibra
# Processing Record 27 of Set 5 | oistins
# Processing Record 28 of Set 5 | port-cartier
# Processing Record 29 of Set 5 | roros
# Processing Record 30 of Set 5 | prince rupert
# Processing Record 31 of Set 5 | upernavik
# Processing Record 32 of Set 5 | burica
# City not found. Skipping...
# Processing Record 33 of Set 5 | gara
# Processing Record 34 of Set 5 | norman wells
# Processing Record 35 of Set 5 | bilma
# Processing Record 36 of Set 5 | barawe
# City not found. Skipping...
# Processing Record 37 of Set 5 | batemans bay
# Processing Record 38 of Set 5 | sid
# Processing Record 39 of Set 5 | westport
# Processing Record 40 of Set 5 | gambela
# Processing Record 41 of Set 5 | kangaatsiaq
# Processing Record 42 of Set 5 | kudahuvadhoo
# Processing Record 43 of Set 5 | haines junction
# Processing Record 44 of Set 5 | taonan
# Processing Record 45 of Set 5 | makakilo city
# Processing Record 46 of Set 5 | guerrero negro
# Processing Record 47 of Set 5 | uruguaiana
# Processing Record 48 of Set 5 | tala
# Processing Record 49 of Set 5 | presidencia roque saenz pena
# Processing Record 50 of Set 5 | samusu
# City not found. Skipping...
# Processing Record 1 of Set 6 | coquimbo
# Processing Record 2 of Set 6 | henties bay
# Processing Record 3 of Set 6 | zyryanka
# Processing Record 4 of Set 6 | inuvik
# Processing Record 5 of Set 6 | conceicao da barra
# Processing Record 6 of Set 6 | vanavara
# Processing Record 7 of Set 6 | saint george
# Processing Record 8 of Set 6 | pacifica
# Processing Record 9 of Set 6 | hobyo
# Processing Record 10 of Set 6 | porto velho
# Processing Record 11 of Set 6 | chokurdakh
# Processing Record 12 of Set 6 | pitimbu
# Processing Record 13 of Set 6 | touros
# Processing Record 14 of Set 6 | hami
# Processing Record 15 of Set 6 | yar-sale
# Processing Record 16 of Set 6 | portland
# Processing Record 17 of Set 6 | ismailia
# Processing Record 18 of Set 6 | caravelas
# Processing Record 19 of Set 6 | mersing
# Processing Record 20 of Set 6 | vao
# Processing Record 21 of Set 6 | mozelos
# Processing Record 22 of Set 6 | huilong
# Processing Record 23 of Set 6 | santa maria
# Processing Record 24 of Set 6 | price
# Processing Record 25 of Set 6 | lourdes
# Processing Record 26 of Set 6 | marakkanam
# Processing Record 27 of Set 6 | dunedin
# Processing Record 28 of Set 6 | fatsa
# Processing Record 29 of Set 6 | hovd
# Processing Record 30 of Set 6 | astana
# Processing Record 31 of Set 6 | airai
# Processing Record 32 of Set 6 | kavieng
# Processing Record 33 of Set 6 | gat
# Processing Record 34 of Set 6 | meshchovsk
# Processing Record 35 of Set 6 | taltal
# Processing Record 36 of Set 6 | laguna
# Processing Record 37 of Set 6 | kirakira
# Processing Record 38 of Set 6 | salinopolis
# Processing Record 39 of Set 6 | balud
# Processing Record 40 of Set 6 | port keats
# Processing Record 41 of Set 6 | fort nelson
# Processing Record 42 of Set 6 | korla
# Processing Record 43 of Set 6 | abu samrah
# Processing Record 44 of Set 6 | srednekolymsk
# Processing Record 45 of Set 6 | samarai
# Processing Record 46 of Set 6 | acapulco
# Processing Record 47 of Set 6 | klaksvik
# Processing Record 48 of Set 6 | rundu
# Processing Record 49 of Set 6 | pacific grove
# Processing Record 50 of Set 6 | saryozek
# Processing Record 1 of Set 7 | manutuke
# Processing Record 2 of Set 7 | barreirinha
# Processing Record 3 of Set 7 | naze
# Processing Record 4 of Set 7 | kloulklubed
# Processing Record 5 of Set 7 | srandakan
# Processing Record 6 of Set 7 | bondo
# Processing Record 7 of Set 7 | madang
# Processing Record 8 of Set 7 | hanmer springs
# Processing Record 9 of Set 7 | bouza
# Processing Record 10 of Set 7 | mabaruma
# Processing Record 11 of Set 7 | dali
# Processing Record 12 of Set 7 | inta
# Processing Record 13 of Set 7 | zhigansk
# Processing Record 14 of Set 7 | phibun mangsahan
# Processing Record 15 of Set 7 | yauya
# Processing Record 16 of Set 7 | praia da vitoria
# Processing Record 17 of Set 7 | san quintin
# Processing Record 18 of Set 7 | skibbereen
# Processing Record 19 of Set 7 | la ronge
# Processing Record 20 of Set 7 | santa helena
# Processing Record 21 of Set 7 | vengerovo
# Processing Record 22 of Set 7 | ahipara
# Processing Record 23 of Set 7 | khasan
# Processing Record 24 of Set 7 | mount pleasant
# Processing Record 25 of Set 7 | semporna
# Processing Record 26 of Set 7 | provideniya
# Processing Record 27 of Set 7 | concepcion
# Processing Record 28 of Set 7 | kaeo
# Processing Record 29 of Set 7 | newport
# Processing Record 30 of Set 7 | natal
# Processing Record 31 of Set 7 | avanigadda
# Processing Record 32 of Set 7 | thinadhoo
# Processing Record 33 of Set 7 | vostok
# Processing Record 34 of Set 7 | ojinaga
# Processing Record 35 of Set 7 | vila
# Processing Record 36 of Set 7 | kadaya
# Processing Record 37 of Set 7 | sao joao da barra
# Processing Record 38 of Set 7 | panuco
# Processing Record 39 of Set 7 | jizan
# Processing Record 40 of Set 7 | severo-kurilsk
# Processing Record 41 of Set 7 | kathu
# Processing Record 42 of Set 7 | roald
# Processing Record 43 of Set 7 | gimli
# Processing Record 44 of Set 7 | almaznyy
# Processing Record 45 of Set 7 | lebu
# Processing Record 46 of Set 7 | talcahuano
# Processing Record 47 of Set 7 | shelburne
# Processing Record 48 of Set 7 | saleaula
# City not found. Skipping...
# Processing Record 49 of Set 7 | khanu woralaksaburi
# Processing Record 50 of Set 7 | nouadhibou
# Processing Record 1 of Set 8 | sao filipe
# Processing Record 2 of Set 8 | kovur
# Processing Record 3 of Set 8 | labuhan
# Processing Record 4 of Set 8 | visnes
# Processing Record 5 of Set 8 | lundazi
# Processing Record 6 of Set 8 | jishou
# Processing Record 7 of Set 8 | friesoythe
# Processing Record 8 of Set 8 | varna
# Processing Record 9 of Set 8 | mutsamudu
# City not found. Skipping...
# Processing Record 10 of Set 8 | lasa
# Processing Record 11 of Set 8 | subtanjalla
# Processing Record 12 of Set 8 | jacqueville
# Processing Record 13 of Set 8 | jiuquan
# Processing Record 14 of Set 8 | mporokoso
# Processing Record 15 of Set 8 | college
# Processing Record 16 of Set 8 | palmer
# Processing Record 17 of Set 8 | seljord
# Processing Record 18 of Set 8 | charlestown
# Processing Record 19 of Set 8 | tongchuan
# Processing Record 20 of Set 8 | jandaia do sul
# Processing Record 21 of Set 8 | kholtoson
# Processing Record 22 of Set 8 | port blair
# Processing Record 23 of Set 8 | amapa
# Processing Record 24 of Set 8 | nieuw amsterdam
# Processing Record 25 of Set 8 | aflu
# City not found. Skipping...
# Processing Record 26 of Set 8 | martapura
# Processing Record 27 of Set 8 | balabac
# Processing Record 28 of Set 8 | chandler
# Processing Record 29 of Set 8 | kaolinovo
# Processing Record 30 of Set 8 | mogochin
# City not found. Skipping...
# Processing Record 31 of Set 8 | necochea
# Processing Record 32 of Set 8 | mecca
# Processing Record 33 of Set 8 | ballina
# Processing Record 34 of Set 8 | qasigiannguit
# Processing Record 35 of Set 8 | peru
# Processing Record 36 of Set 8 | mizque
# Processing Record 37 of Set 8 | satitoa
# City not found. Skipping...
# Processing Record 38 of Set 8 | abu zabad
# Processing Record 39 of Set 8 | pastavy
# Processing Record 40 of Set 8 | labytnangi
# Processing Record 41 of Set 8 | cabo san lucas
# Processing Record 42 of Set 8 | najran
# Processing Record 43 of Set 8 | sola
# Processing Record 44 of Set 8 | shache
# Processing Record 45 of Set 8 | tungor
# Processing Record 46 of Set 8 | changping
# Processing Record 47 of Set 8 | jiazi
# Processing Record 48 of Set 8 | koster
# Processing Record 49 of Set 8 | bargal
# City not found. Skipping...
# Processing Record 50 of Set 8 | abalak
# Processing Record 1 of Set 9 | eyl
# Processing Record 2 of Set 9 | maler kotla
# Processing Record 3 of Set 9 | umzimvubu
# City not found. Skipping...
# Processing Record 4 of Set 9 | shakhtinsk
# Processing Record 5 of Set 9 | vila velha
# Processing Record 6 of Set 9 | aksarayskiy
# Processing Record 7 of Set 9 | louisbourg
# City not found. Skipping...
# Processing Record 8 of Set 9 | mandalgovi
# Processing Record 9 of Set 9 | nalut
# Processing Record 10 of Set 9 | challapata
# Processing Record 11 of Set 9 | nizwa
# Processing Record 12 of Set 9 | zemio
# Processing Record 13 of Set 9 | esperance
# Processing Record 14 of Set 9 | chimbarongo
# Processing Record 15 of Set 9 | novoagansk
# Processing Record 16 of Set 9 | bonthe
# Processing Record 17 of Set 9 | pokrovsk
# Processing Record 18 of Set 9 | viligili
# City not found. Skipping...
# Processing Record 19 of Set 9 | vynohradove
# Processing Record 20 of Set 9 | homer
# Processing Record 21 of Set 9 | mishan
# Processing Record 22 of Set 9 | morgan city
# Processing Record 23 of Set 9 | mandali
# Processing Record 24 of Set 9 | aklavik
# Processing Record 25 of Set 9 | tipuani
# Processing Record 26 of Set 9 | buraydah
# Processing Record 27 of Set 9 | keuruu
# Processing Record 28 of Set 9 | grand centre
# City not found. Skipping...
# Processing Record 29 of Set 9 | grand-lahou
# Processing Record 30 of Set 9 | san angelo
# Processing Record 31 of Set 9 | ormara
# Processing Record 32 of Set 9 | assiniboia
# Processing Record 33 of Set 9 | nyzhnya krynka
# Processing Record 34 of Set 9 | xining
# Processing Record 35 of Set 9 | eydhafushi
# Processing Record 36 of Set 9 | vilhena
# Processing Record 37 of Set 9 | dauriya
# Processing Record 38 of Set 9 | uyemskiy
# Processing Record 39 of Set 9 | kamaishi
# Processing Record 40 of Set 9 | sao felix do xingu
# Processing Record 41 of Set 9 | broome
# Processing Record 42 of Set 9 | youkounkoun
# Processing Record 43 of Set 9 | izvestkovyy
# Processing Record 44 of Set 9 | santander
# Processing Record 45 of Set 9 | sinjar
# Processing Record 46 of Set 9 | raudeberg
# Processing Record 47 of Set 9 | los llanos de aridane
# Processing Record 48 of Set 9 | queanbeyan
# Processing Record 49 of Set 9 | ishcherskaya
# Processing Record 50 of Set 9 | krasnoselkup
# Processing Record 1 of Set 10 | tsabong
# Processing Record 2 of Set 10 | sidney
# Processing Record 3 of Set 10 | paka
# Processing Record 4 of Set 10 | chernyy yar
# Processing Record 5 of Set 10 | conceicao do araguaia
# Processing Record 6 of Set 10 | jericho
# Processing Record 7 of Set 10 | shestakovo
# Processing Record 8 of Set 10 | san rafael
# Processing Record 9 of Set 10 | pangnirtung
# Processing Record 10 of Set 10 | narsaq
# Processing Record 11 of Set 10 | marino
# Processing Record 12 of Set 10 | kingston
# Processing Record 13 of Set 10 | deputatskiy
# Processing Record 14 of Set 10 | ogbomosho
# Processing Record 15 of Set 10 | bagotville
# Processing Record 16 of Set 10 | omboue
# Processing Record 17 of Set 10 | songjianghe
# Processing Record 18 of Set 10 | tevriz
# Processing Record 19 of Set 10 | upington
# Processing Record 20 of Set 10 | shakawe
# Processing Record 21 of Set 10 | san pedro de macoris
# Processing Record 22 of Set 10 | muisne
# Processing Record 23 of Set 10 | port-gentil
# Processing Record 24 of Set 10 | mombetsu
# Processing Record 25 of Set 10 | altamira
# Processing Record 26 of Set 10 | orange
# Processing Record 27 of Set 10 | barbar
# City not found. Skipping...
# Processing Record 28 of Set 10 | mahadday weyne
# City not found. Skipping...
# Processing Record 29 of Set 10 | labuan
# Processing Record 30 of Set 10 | havre-saint-pierre
# Processing Record 31 of Set 10 | leningradskiy
# Processing Record 32 of Set 10 | hailey
# Processing Record 33 of Set 10 | sao gabriel da cachoeira
# Processing Record 34 of Set 10 | tual
# Processing Record 35 of Set 10 | tucuman
# Processing Record 36 of Set 10 | san cristobal
# Processing Record 37 of Set 10 | kolar
# Processing Record 38 of Set 10 | matsanga
# City not found. Skipping...
# Processing Record 39 of Set 10 | huarmey
# Processing Record 40 of Set 10 | arlit
# Processing Record 41 of Set 10 | merke
# Processing Record 42 of Set 10 | marcona
# City not found. Skipping...
# Processing Record 43 of Set 10 | manokwari
# Processing Record 44 of Set 10 | alotau
# City not found. Skipping...
# Processing Record 45 of Set 10 | shizunai
# Processing Record 46 of Set 10 | pochutla
# Processing Record 47 of Set 10 | svetlyy
# Processing Record 48 of Set 10 | nakhon thai
# Processing Record 49 of Set 10 | bosaso
# Processing Record 50 of Set 10 | lolua
# City not found. Skipping...
# Processing Record 1 of Set 11 | haskovo
# Processing Record 2 of Set 11 | geraldton
# Processing Record 3 of Set 11 | thessalon
# Processing Record 4 of Set 11 | terrace
# Processing Record 5 of Set 11 | hofn
# Processing Record 6 of Set 11 | wilmington
# Processing Record 7 of Set 11 | carberry
# Processing Record 8 of Set 11 | karratha
# Processing Record 9 of Set 11 | lichinga
# Processing Record 10 of Set 11 | anadyr
# Processing Record 11 of Set 11 | russell
# Processing Record 12 of Set 11 | beatrice
# Processing Record 13 of Set 11 | biak
# Processing Record 14 of Set 11 | lorvao
# Processing Record 15 of Set 11 | salalah
# Processing Record 16 of Set 11 | faya
# Processing Record 17 of Set 11 | smithers
# Processing Record 18 of Set 11 | gorontalo
# Processing Record 19 of Set 11 | basco
# Processing Record 20 of Set 11 | yabrud
# Processing Record 21 of Set 11 | talwandi bhai
# Processing Record 22 of Set 11 | kamenka
# Processing Record 23 of Set 11 | changji
# Processing Record 24 of Set 11 | hambantota
# Processing Record 25 of Set 11 | bow island
# Processing Record 26 of Set 11 | nuuk
# Processing Record 27 of Set 11 | san ignacio
# Processing Record 28 of Set 11 | vestmannaeyjar
# Processing Record 29 of Set 11 | alvaraes
# Processing Record 30 of Set 11 | ust-abakan
# Processing Record 31 of Set 11 | constitucion
# Processing Record 32 of Set 11 | venancio aires
# Processing Record 33 of Set 11 | nandikotkur
# Processing Record 34 of Set 11 | pouebo
# Processing Record 35 of Set 11 | koungou
# Processing Record 36 of Set 11 | taoudenni
# Processing Record 37 of Set 11 | xintai
# Processing Record 38 of Set 11 | wuwei
# Processing Record 39 of Set 11 | moron
# Processing Record 40 of Set 11 | leshukonskoye
# Processing Record 41 of Set 11 | buin
# Processing Record 42 of Set 11 | saskylakh
# Processing Record 43 of Set 11 | port antonio
# Processing Record 44 of Set 11 | gannan
# Processing Record 45 of Set 11 | tautira
# Processing Record 46 of Set 11 | tunduru
# City not found. Skipping...
# Processing Record 47 of Set 11 | azimur
# City not found. Skipping...
# Processing Record 48 of Set 11 | shamary
# Processing Record 49 of Set 11 | tra vinh
# Processing Record 50 of Set 11 | vaitape
# Processing Record 1 of Set 12 | dagami
# Processing Record 2 of Set 12 | kailua
# Processing Record 3 of Set 12 | imbituba
# Processing Record 4 of Set 12 | mehamn
# Processing Record 5 of Set 12 | ostrovnoy
# Processing Record 6 of Set 12 | noumea
# Processing Record 7 of Set 12 | ust-kuyga
# Processing Record 8 of Set 12 | pinega
# Processing Record 9 of Set 12 | ardmore
# Processing Record 10 of Set 12 | komsomolskiy
# Processing Record 11 of Set 12 | wattegama
# Processing Record 12 of Set 12 | sarakhs
# Processing Record 13 of Set 12 | charleston
# Processing Record 14 of Set 12 | baijiantan
# Processing Record 15 of Set 12 | veraval
# Processing Record 16 of Set 12 | aykhal
# Processing Record 17 of Set 12 | goderich
# Processing Record 18 of Set 12 | el limon
# Processing Record 19 of Set 12 | parlakimidi
# Processing Record 20 of Set 12 | gamboma
# Processing Record 21 of Set 12 | phan thiet
# Processing Record 22 of Set 12 | codrington
# Processing Record 23 of Set 12 | concordia
# Processing Record 24 of Set 12 | beaumont
# Processing Record 25 of Set 12 | itarema
# Processing Record 26 of Set 12 | mao
# Processing Record 27 of Set 12 | hit
# Processing Record 28 of Set 12 | saryshagan
# City not found. Skipping...
# Processing Record 29 of Set 12 | celestun
# Processing Record 30 of Set 12 | palmerston
# Processing Record 31 of Set 12 | khandyga
# Processing Record 32 of Set 12 | filingue
# Processing Record 33 of Set 12 | huainan
# Processing Record 34 of Set 12 | santa cruz de rosales
# City not found. Skipping...
# Processing Record 35 of Set 12 | maragogi
# Processing Record 36 of Set 12 | shieli
# Processing Record 37 of Set 12 | wuning
# Processing Record 38 of Set 12 | sarmanovo
# Processing Record 39 of Set 12 | gazanjyk
# Processing Record 40 of Set 12 | valdemarpils
# Processing Record 41 of Set 12 | khorramshahr
# Processing Record 42 of Set 12 | beloha
# Processing Record 43 of Set 12 | jaguariaiva
# Processing Record 44 of Set 12 | mildura
# Processing Record 45 of Set 12 | krasnyy chikoy
# Processing Record 46 of Set 12 | debre sina
# Processing Record 47 of Set 12 | vaitupu
# City not found. Skipping...
# Processing Record 48 of Set 12 | dahra
# Processing Record 49 of Set 12 | sioux lookout
# Processing Record 50 of Set 12 | loncoche
# Processing Record 1 of Set 13 | ilebo
# Processing Record 2 of Set 13 | perelyub
# Processing Record 3 of Set 13 | maymyo
# Processing Record 4 of Set 13 | meadow lake
# Processing Record 5 of Set 13 | blackwater
# Processing Record 6 of Set 13 | hebertville
# City not found. Skipping...
# Processing Record 7 of Set 13 | ixcaquixtla
# City not found. Skipping...
# Processing Record 8 of Set 13 | hamilton
# Processing Record 9 of Set 13 | geelong
# Processing Record 10 of Set 13 | peterhead
# Processing Record 11 of Set 13 | kitimat
# Processing Record 12 of Set 13 | ulagan
# Processing Record 13 of Set 13 | madera
# Processing Record 14 of Set 13 | trapani
# Processing Record 15 of Set 13 | osakarovka
# Processing Record 16 of Set 13 | kulhudhuffushi
# Processing Record 17 of Set 13 | ancud
# Processing Record 18 of Set 13 | sabha
# Processing Record 19 of Set 13 | kalianget
# Processing Record 20 of Set 13 | arawa
# Processing Record 21 of Set 13 | xiongshi
# City not found. Skipping...
# Processing Record 22 of Set 13 | coyuca
# City not found. Skipping...
# Processing Record 23 of Set 13 | kalmar
# Processing Record 24 of Set 13 | megion
# Processing Record 25 of Set 13 | chervonohryhorivka
# Processing Record 26 of Set 13 | nguru
# Processing Record 27 of Set 13 | katobu
# Processing Record 28 of Set 13 | hyeres
# Processing Record 29 of Set 13 | okato
# Processing Record 30 of Set 13 | west plains
# Processing Record 31 of Set 13 | tadine
# Processing Record 32 of Set 13 | vargem grande
# Processing Record 33 of Set 13 | bolungarvik
# City not found. Skipping...
# Processing Record 34 of Set 13 | ngukurr
# City not found. Skipping...
# Processing Record 35 of Set 13 | oktyabrskiy
# Processing Record 36 of Set 13 | shubarkuduk
# Processing Record 37 of Set 13 | santa maria del oro
# Processing Record 38 of Set 13 | zaraza
# Processing Record 39 of Set 13 | aketi
# Processing Record 40 of Set 13 | saint anthony
# Processing Record 41 of Set 13 | kazalinsk
# City not found. Skipping...
# Processing Record 42 of Set 13 | plattsburgh
# Processing Record 43 of Set 13 | marsabit
# Processing Record 44 of Set 13 | bogatyr
# Processing Record 45 of Set 13 | sambir
# Processing Record 46 of Set 13 | cayenne
# Processing Record 47 of Set 13 | tazovskiy
# Processing Record 48 of Set 13 | malindi
# Processing Record 49 of Set 13 | finschhafen
# Processing Record 50 of Set 13 | taga
# Processing Record 1 of Set 14 | chinsali
# Processing Record 2 of Set 14 | meulaboh
# Processing Record 3 of Set 14 | antalaha
# Processing Record 4 of Set 14 | preobrazheniye
# Processing Record 5 of Set 14 | taksimo
# Processing Record 6 of Set 14 | turukhansk
# Processing Record 7 of Set 14 | miraflores
# Processing Record 8 of Set 14 | ao luk
# City not found. Skipping...
# Processing Record 9 of Set 14 | fort walton beach
# Processing Record 10 of Set 14 | magnolia
# Processing Record 11 of Set 14 | uruzgan
# Processing Record 12 of Set 14 | dillon
# Processing Record 13 of Set 14 | tamasane
# Processing Record 14 of Set 14 | manono
# Processing Record 15 of Set 14 | kandra
# Processing Record 16 of Set 14 | puerto escondido
# Processing Record 17 of Set 14 | xudat
# Processing Record 18 of Set 14 | khvalynsk
# Processing Record 19 of Set 14 | honningsvag
# Processing Record 20 of Set 14 | ondjiva
# Processing Record 21 of Set 14 | aksu
# Processing Record 22 of Set 14 | tchollire
# Processing Record 23 of Set 14 | knysna
# Processing Record 24 of Set 14 | ye
# City not found. Skipping...
# Processing Record 25 of Set 14 | santiago del estero
# Processing Record 26 of Set 14 | akyab
# Processing Record 27 of Set 14 | camacha
# Processing Record 28 of Set 14 | poya
# Processing Record 29 of Set 14 | goundam
# Processing Record 30 of Set 14 | muros
# Processing Record 31 of Set 14 | dudinka
# Processing Record 32 of Set 14 | valparaiso
# Processing Record 33 of Set 14 | gambo
# Processing Record 34 of Set 14 | southbridge
# Processing Record 35 of Set 14 | jumla
# Processing Record 36 of Set 14 | galle
# Processing Record 37 of Set 14 | panzhihua
# Processing Record 38 of Set 14 | fornosovo
# Processing Record 39 of Set 14 | mahebourg
# Processing Record 40 of Set 14 | guiyang
# Processing Record 41 of Set 14 | searcy
# Processing Record 42 of Set 14 | olinda
# Processing Record 43 of Set 14 | wlingi
# Processing Record 44 of Set 14 | ordu
# Processing Record 45 of Set 14 | gurskoye
# City not found. Skipping...
# Processing Record 46 of Set 14 | cap estate
# Processing Record 47 of Set 14 | mbini
# Processing Record 48 of Set 14 | bhunya
# Processing Record 49 of Set 14 | waingapu
# Processing Record 50 of Set 14 | tuggurt
# City not found. Skipping...
# Processing Record 1 of Set 15 | qaqortoq
# Processing Record 2 of Set 15 | salisbury
# Processing Record 3 of Set 15 | eskasem
# City not found. Skipping...
# Processing Record 4 of Set 15 | kamenskoye
# City not found. Skipping...
# Processing Record 5 of Set 15 | diego de almagro
# Processing Record 6 of Set 15 | warqla
# City not found. Skipping...
# Processing Record 7 of Set 15 | balkhash
# Processing Record 8 of Set 15 | harper
# Processing Record 9 of Set 15 | portree
# Processing Record 10 of Set 15 | stromness
# Processing Record 11 of Set 15 | songea
# Processing Record 12 of Set 15 | trat
# Processing Record 13 of Set 15 | guiratinga
# Processing Record 14 of Set 15 | malm
# Processing Record 15 of Set 15 | sfantu gheorghe
# Processing Record 16 of Set 15 | doha
# Processing Record 17 of Set 15 | cururupu
# Processing Record 18 of Set 15 | janossomorja
# Processing Record 19 of Set 15 | kysyl-syr
# Processing Record 20 of Set 15 | san vicente
# Processing Record 21 of Set 15 | centenario do sul
# Processing Record 22 of Set 15 | berlevag
# Processing Record 23 of Set 15 | lerwick
# Processing Record 24 of Set 15 | mnogovershinnyy
# Processing Record 25 of Set 15 | seoul
# Processing Record 26 of Set 15 | belaya gora
# Processing Record 27 of Set 15 | mugumu
# Processing Record 28 of Set 15 | ulaanbaatar
# Processing Record 29 of Set 15 | energeticheskiy
# Processing Record 30 of Set 15 | burnie
# Processing Record 31 of Set 15 | burley
# Processing Record 32 of Set 15 | moroni
# Processing Record 33 of Set 15 | dukat
# Processing Record 34 of Set 15 | chara
# Processing Record 35 of Set 15 | temaraia
# City not found. Skipping...
# Processing Record 36 of Set 15 | harindanga
# Processing Record 37 of Set 15 | muskogee
# Processing Record 38 of Set 15 | cape canaveral
# Processing Record 39 of Set 15 | odweyne
# Processing Record 40 of Set 15 | iquique
# Processing Record 41 of Set 15 | vrede
# Processing Record 42 of Set 15 | sakaraha
# Processing Record 43 of Set 15 | aldan
# Processing Record 44 of Set 15 | kijang
# Processing Record 45 of Set 15 | zavodskoy
# Processing Record 46 of Set 15 | upata
# Processing Record 47 of Set 15 | kaputa
# Processing Record 48 of Set 15 | we
# City not found. Skipping...
# Processing Record 49 of Set 15 | luchegorsk
# Processing Record 50 of Set 15 | oranjemund
# Processing Record 1 of Set 16 | banjar
# Processing Record 2 of Set 16 | batagay-alyta
# Processing Record 3 of Set 16 | kyshtovka
# Processing Record 4 of Set 16 | fairhope
# Processing Record 5 of Set 16 | ornskoldsvik
# Processing Record 6 of Set 16 | kulykiv
# Processing Record 7 of Set 16 | koppies
# Processing Record 8 of Set 16 | north bend
# Processing Record 9 of Set 16 | aloleng
# Processing Record 10 of Set 16 | kankaanpaa
# Processing Record 11 of Set 16 | bandundu
# Processing Record 12 of Set 16 | alofi
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 702

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0          Rikitea -23.1203 -134.9692     79.09        78         100
# 1            Bluff -46.6000  168.3333     55.80        78          95
# 2           Castro -24.7911  -50.0119     78.48        60           0
# 3         Krumbach  48.2418   10.3632     32.65        89         100
# 4         Victoria  22.2855  114.1577     58.24        74          13
# 5            Olden  61.8364    6.8064     39.94        99         100
# 6          Ushuaia -54.8000  -68.3000     47.82        76          75
# 7          Kahului  20.8947 -156.4700     77.85        75          20
# 8           Hobart -42.8794  147.3294     60.66        63          40
# 9  Port Hawkesbury  45.6169  -61.3485     27.99        69          20
#
#    Wind Speed Country Current Description
# 0       16.53      PF     overcast clouds
# 1        8.72      NZ     overcast clouds
# 2        7.18      BR           clear sky
# 3        5.97      DE     overcast clouds
# 4        8.99      HK          few clouds
# 5        5.70      NO     overcast clouds
# 6       14.97      AR          light rain
# 7        4.00      US          light rain
# 8       17.27      AU    scattered clouds
# 9       12.66      CA          few clouds

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country', 'Current Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]

# Recreate the DataFrame by using the new column order
city_data_df = city_data_df[new_column_order]

# Display sample data
city_data_df.head(10)
# Out:
#               City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0          Rikitea      PF -23.1203 -134.9692     79.09        78         100
# 1            Bluff      NZ -46.6000  168.3333     55.80        78          95
# 2           Castro      BR -24.7911  -50.0119     78.48        60           0
# 3         Krumbach      DE  48.2418   10.3632     32.65        89         100
# 4         Victoria      HK  22.2855  114.1577     58.24        74          13
# 5            Olden      NO  61.8364    6.8064     39.94        99         100
# 6          Ushuaia      AR -54.8000  -68.3000     47.82        76          75
# 7          Kahului      US  20.8947 -156.4700     77.85        75          20
# 8           Hobart      AU -42.8794  147.3294     60.66        63          40
# 9  Port Hawkesbury      CA  45.6169  -61.3485     27.99        69          20
#
#    Wind Speed Current Description
# 0       16.53     overcast clouds
# 1        8.72     overcast clouds
# 2        7.18           clear sky
# 3        5.97     overcast clouds
# 4        8.99          few clouds
# 5        5.70     overcast clouds
# 6       14.97          light rain
# 7        4.00          light rain
# 8       17.27    scattered clouds
# 9       12.66          few clouds

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data_file = "WeatherPy_Database.csv"

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_data_file, index_label="City_ID")
